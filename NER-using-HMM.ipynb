# %%
from sklearn import metrics
with open("PATH") as fh:
    train_lines = fh.readlines()

# %%
#tuple each tagged word inside a list
array_tutucu=[]
t_tutucu=[]
for asa in train_lines:
    k=asa.split()
    array_tutucu.append(k)
for a in array_tutucu:
    tu=tuple(a)
    t_tutucu.append(tu)

# %%
print(t_tutucu[0:50])
# Out:
# [('ATİLLA', 'B-PERSON'), ('Mutman', 'I-PERSON'), (',', 'O'), ('İzmir', 'B-LOCATION'), ('milletvekili', 'O'), (), ('Gecenin', 'O'), ('erken', 'O'), ('saatlerinde', 'O'), ('de', 'O'), (',', 'O'), ('belli', 'O'), ('olacak', 'O'), ('Avrupa', 'B-LOCATION'), ("'", 'O'), ('nın', 'O'), ('en', 'O'), ('büyük', 'O'), ('ülkesinin', 'O'), ('hükümetini', 'O'), ('kimin', 'O'), ('yöneteceği', 'O'), (), ('Bilgisayarlı', 'O'), ('telefon', 'O'), ('klübesi', 'O'), (), ('Kozmopolit', 'O'), ('bir', 'O'), ('ulus', 'O'), (), ('Yıllık', 'O'), ('10', 'O'), ('milyon', 'O'), ('ton', 'O'), ('kapasitesi', 'O'), ('bulunan', 'O'), ('limana', 'O'), ('150', 'O'), ('bin', 'O'), ('DWT', 'O'), ('tonluk', 'O'), ('gemiler', 'O'), ('yanaşabilecek', 'O'), (), ('Uzanan', 'O'), ('bir', 'O'), ('"', 'O'), ('barış', 'O'), ('eli', 'O')]

# %%
tur_array=[]
genel_array=[]
for sss in t_tutucu:
    if len(sss)!=0:
        tur_array.append(sss)
    else :
        genel_array.append(tur_array)
        tur_array=[]

# %%
token=[]
entity=[]
i=0
for genel in genel_array:
    for tl in genel:
        if len(tl)==2:
            token.append(tl[0])
            entity.append(tl[1])
    
tokens=tuple(token)
entity=tuple(entity) 
print(tokens[0:10])
print(entity[0:10])
# Out:
# ('ATİLLA', 'Mutman', ',', 'İzmir', 'milletvekili', 'Gecenin', 'erken', 'saatlerinde', 'de', ',')
# ('B-PERSON', 'I-PERSON', 'O', 'B-LOCATION', 'O', 'O', 'O', 'O', 'O', 'O')

# %%
#finding the number of word tags at the beginning of the sentence and calculating the probability of their being found
b_location=0
b_organization=0
b_person=1
i_location=0
i_organization=0
i_person=0
o=0
for i in range(len(t_tutucu)-1):
    if len(t_tutucu[i]) < 2:
        if t_tutucu[i+1][1] == "B-LOCATION":
            b_location+=1
        elif t_tutucu[i+1][1] == "B-ORGANIZATION":
            b_organization+=1
        elif t_tutucu[i+1][1] == "B-PERSON":
            b_person+=1
        elif t_tutucu[i+1][1] == "I-LOCATION":
            i_location+=1
        elif t_tutucu[i+1][1] == "I-ORGANIZATION":
            i_organization+=1
        elif t_tutucu[i+1][1] == "I-PERSON":
            i_person+=1
        elif t_tutucu[i+1][1] == "O":
            o+=1
sum=b_location+b_organization+b_person+i_location+i_organization+i_person+o

# %%
import pandas as pd
import numpy as np

from nltk.tag import pos_tag
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
from nltk import word_tokenize

def nltk_tag_to_wordnet_tag(nltk_tag):
    if nltk_tag.startswith('J'):
        return wordnet.ADJ
    elif nltk_tag.startswith('V'):
        return wordnet.VERB
    elif nltk_tag.startswith('N'):
        return wordnet.NOUN
    elif nltk_tag.startswith('R'):
        return wordnet.ADV
    else:          
        return None

def lemmatize_sentence(sentence):
    nltk_tagged = pos_tag(sentence.split())
    wordnet_tagged = map(lambda x: (x[0], nltk_tag_to_wordnet_tag(x[1])), nltk_tagged)
    lemmatized_sentence = []
    for word, tag in wordnet_tagged:
        if tag is None:
            lemmatized_sentence.append(word)
        else:        
            lemmatized_sentence.append(WordNetLemmatizer().lemmatize(word, tag))
    return lemmatized_sentence

# %%
#creating emission matrix
tokens = [lemmatize_sentence(token.lower())[0] for token in tokens]

df = pd.DataFrame(tokens,entity).reset_index().rename(columns={0:'tokens','index':'entity'})
df['values']=1
df = df.pivot_table(index='entity',columns='tokens',aggfunc='sum').fillna(0)
df = df.div(df.sum(axis=1), axis=0)
df.columns = df.columns.droplevel(0)
print(df)
# Out:
# tokens                 "         $         %         &         '         (  \
# entity
# B-LOCATION      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# B-ORGANIZATION  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# B-PERSON        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# I-LOCATION      0.000000  0.000000  0.000000  0.000000  0.003115  0.000000
# I-ORGANIZATION  0.000000  0.000000  0.000000  0.002730  0.004949  0.000000
# I-PERSON        0.000634  0.000000  0.000000  0.000000  0.001267  0.000000
# O               0.023062  0.000003  0.000027  0.000024  0.046473  0.003584
#
# tokens                )         +         ,         -  ...   şüpheyi  \
# entity                                                 ...
# B-LOCATION      0.00000  0.000000  0.000000  0.000000  ...  0.000000
# B-ORGANIZATION  0.00000  0.000000  0.000000  0.000000  ...  0.000000
# B-PERSON        0.00000  0.000000  0.000075  0.000000  ...  0.000000
# I-LOCATION      0.00000  0.000000  0.002336  0.010903  ...  0.000000
# I-ORGANIZATION  0.00000  0.000000  0.001536  0.020307  ...  0.000000
# I-PERSON        0.00000  0.000000  0.000000  0.003801  ...  0.000000
# O               0.00344  0.000027  0.061742  0.006764  ...  0.000003
#
# tokens          şüpnhelenilen     şüyuu       şıh       şık    şıklık  \
# entity
# B-LOCATION           0.000000  0.000000  0.000000  0.000000  0.000000
# B-ORGANIZATION       0.000000  0.000000  0.000000  0.000000  0.000000
# B-PERSON             0.000000  0.000000  0.000000  0.000000  0.000000
# I-LOCATION           0.000000  0.000000  0.000000  0.000000  0.000000
# I-ORGANIZATION       0.000000  0.000000  0.000000  0.000000  0.000000
# I-PERSON             0.000000  0.000000  0.000000  0.000000  0.000000
# O                    0.000003  0.000003  0.000003  0.000021  0.000003
#
# tokens           şımarık    şırnak  şırnaklı         ’
# entity
# B-LOCATION      0.000000  0.002267  0.000000  0.000000
# B-ORGANIZATION  0.000000  0.000000  0.000000  0.000000
# B-PERSON        0.000000  0.000000  0.000000  0.000000
# I-LOCATION      0.000000  0.000000  0.000000  0.000000
# I-ORGANIZATION  0.000000  0.000000  0.000000  0.000000
# I-PERSON        0.000000  0.000000  0.000000  0.000000
# O               0.000003  0.000000  0.000003  0.000005
#
# [7 rows x 56184 columns]

# %%
#Creating transition matrix
df2 = []
for index in range(len(t_tutucu)-1):
    if len(t_tutucu[index+1]) ==2 and len(t_tutucu[index]) ==2 :
        first_token = t_tutucu[index][1]
        next_token = t_tutucu[index+1][1]
        df2.append({'first_token':first_token,'next_token':next_token})
df2 = pd.DataFrame(df2)
df2['values'] = 1
df2 = df2.pivot_table(index='first_token',columns='next_token',aggfunc='sum').fillna(0)
df2 = df2.div(df2.sum(axis=1), axis=0)
df2.columns = df2.columns.droplevel(0)
df2 = pd.concat([pd.DataFrame(columns=['B-LOCATION','I-LOCATION','O','B-ORGANIZATION','B-PERSON','I-ORGANIZATION','I-PERSON'],index=['<s>'],data=[[b_location/sum,i_location/sum,o/sum,b_organization/sum,b_person/sum,i_organization/sum,i_person/sum]]),df2],axis=0)

print(df2)
# Out:
#                 B-LOCATION  I-LOCATION         O  B-ORGANIZATION  B-PERSON  \
# <s>               0.073462    0.000000  0.704629        0.094637  0.127272
# B-LOCATION        0.006657    0.105103  0.885788        0.001985  0.000467
# B-ORGANIZATION    0.008235    0.000000  0.601792        0.002786  0.000484
# B-PERSON          0.002650    0.000000  0.555126        0.001363  0.005982
# I-LOCATION        0.007843    0.301176  0.687059        0.000784  0.003137
# I-ORGANIZATION    0.004281    0.000000  0.535616        0.002568  0.000856
# I-PERSON          0.003838    0.000000  0.896028        0.003338  0.001502
# O                 0.019638    0.000000  0.933962        0.017229  0.029171
#
#                 I-ORGANIZATION  I-PERSON
# <s>                   0.000000  0.000000
# B-LOCATION            0.000000  0.000000
# B-ORGANIZATION        0.386702  0.000000
# B-PERSON              0.000000  0.434878
# I-LOCATION            0.000000  0.000000
# I-ORGANIZATION        0.456678  0.000000
# I-PERSON              0.000000  0.095294
# O                     0.000000  0.000000

# %%
with open(r"PATH",encoding="utf8") as fh:
    test_lines = fh.readlines()

# %%
array_tutucu=[]
t_tutucu=[]
m_test=[]
for asa in test_lines:
    k=asa.split()
    array_tutucu.append(k)
for x in array_tutucu:
    if len(x) ==2:
        m_test.append(x[1])
print(len(m_test))
# Out:
# 49600

# %%
testMetin=""
for test in array_tutucu:
    if len(test)==2:
        testMetin = testMetin + test[0] +" "
print(testMetin)
# Out:
# Bunlar , mücadelenin kesin galibini belirleyecek bir sayısal güce sahip bulunuyorlar Bugünkü mücadele , Savaş sonrası Fedaral Almanya Cumhuriyeti ' nin kuruluşundan bu yana 14ncü , iki Almanya ' nın birlişmesinden sonra da 3 . ve 20 . yüzyılın son seçimi 20 . yüzyılın son genel seçimlerinde de daha önce olduğu gibi merkez sağın lokomotifi ' Rekortmen Başbakan ' Helmut Kohl ile 16 yıldır muhalefette olan Sosyal Demokratların başbakan adayı Gerhard Schröder mücadele edecek Fark çok az Şimdiye dek yapılan kamuoyu yoklamaları ve uzmanların görüşlerine göre , yarınki seçimlerde iki taraf başabaş bir mücadele verecek Son kamuoyu yoklamalarında alınan sonuçlar , 1998 başında süratle irtifa kaybeden ve Schröder ' in 10 - 12 puan gerisine düşen Helmut Kohl ' ün son haftalarda bu farkı kapattığı ve iki gün önce yüzde 2 ' ye kadar düşürdüğü belirlendi Ancak dünkü verilerde Sosyal Demokratlar 4 puan önde göründüler Allensbach Seçim Enstitüsü ' nün düzenlediği son kamuoyu yoklaması , SPD ' nin oy oranının geçen haftaya göre yüzde 41 . 1 ' den 40 . 5 ' e , Başbakan Helmut Kohl ' ün Muhafazakar Partisi CDU ' nun da 0 . 1 puan düşerek yüzde 36 ' ya gerilediğini ortaya koydu Kararsızların rolü Bu sonuçlardan yola çıkan uzmanlar , yarınki seçimlerde oranları yüzde 20 ' ye yaklaşan kararsızların sonucu belirleyeceği görüşünde birleştiler Nitekim gerek Kohl , gerekse Schröder son seçim konuşmalarında kararsız oyları kendi taraflarına çekmek için büyük çaba sarfettiler Helmut Kohl ' ün aradaki farkı kapatmasında da kararsız seçmenlerin bir bölümünü merkez sağa çekmesinin rol oynadığı ileri sürüldü Büyük koalisyona doğru Kamuoyu yoklamaları ve diğer araştırmalar , ne merkez sağın ne de SPD ve Yeşiller ' den oluşan solun oy oranının yüzde 50 ' yi aşamayacağını ortaya koydu Son anketlere göre SPD ' nin oy oranı yüzde 40 - 42 , Yeşiller ' inki de yüzde 5 - 6 , 5 olduğu saptandı Birlik Partileri ' nin ( CDU / CSU ) toplayacağı oy oranının da yüzde 40 ' ı bulmayacağı yüzde 37 ile 39 orasında olacağı saptandı Birlik partilerinin ortağı Hür Demokratlar ' ın yüzde 5 barajını güçlükle aşacağı ve aşsa bile ancak oylarının yüzde 5 - 6 arasında olacağı belirlendi Bu durumda , iki taraf da yüzde 50 ' yi aşamayacağı için istedikleri biçimde bir koalisyon kuramayacaklar ve ortada büyük koalisyondan başka seçenek kalmayacak gibi görünüyor Kohl , seçim kampanyasının başlangıcında , bir " büyük koalisyona asla razı olmayacağını " söyledi fakat gelişmeler Hırıstiyan Demokrat liderin bu görüşünde gedik açtı Uzmanlar , çok önemli sürprizler olmazsa Almanya ' nın gelecek dönemdeki hükümetinin " büyük koalisyon " ile oluşacağını ifade ediyorlar 3 milyon 300 bin yeni seçmen Seçim istatistiklerinde seçme hakkına sahip olan 60 , 5 milyon seçmenden 31 milyon 800 bininin kadın , 28 milyon 800 bininin de erkek olduğu ortaya çıktı Seçmen yaşı 18 olan Almanya ' da yarınki seçimlerde 3 milyon 300 bin kişi ilk kez oy kullanacak Bu seçimde oy hakkına sahip olan yaklaşık Türk asıllı 160 bin Alman , kampaanya boyunca sürekli ilgi odağı oldu Uzamanların belirttiklerine göre , bir sonraki seçimlerde , Türk asıllı Alman seçmen sayısının 500 bine çıkacağı hesaplanıyor 16 trilyonluk seçim 160 bini Türk asıllı olmak üzere 60 , 5 milyon seçmenin oy sandığına gitmesi beklenen genel seçimlerin maliyeti , 100 milyon mark ( yaklaşık 16 . 5 trilyon TL ) olarak hesaplandı Diğer bir ifadeyle , her bir oyun maliyeti , 2 mark 10 fenig 1994 genel seçimlerinin maliyeti ise 98 milyon 672 bin mark olarak hesaplanmıştı Buna karşılık 1953 yılında yapılan seçimler sadece 4 , 6 milyon marka mal olmuştu Yapılan hesaplara göre , binde 5 oranında oy alan tüm siyasi partiler , aldıkları her oy için yılda 1 mark , ilk 5 milyon oyun her biri için de 1 mark 30 fenig para alacak ÇEŞİTLİ siyasi partilerin Türk asıllı milletvekili adayları , Türk asıllı seçmenlere yaptıkları ortak çağrıda , sandık başına giderek , oylarını kullanmalarını istediler Almanya ' da siyasete atılan ve aday olan Türklerin en ilginci , ırkçı ...

# %%
test_1= testMetin
list_of_entity = []
previous = "<s>"
tokens = [lemmatize_sentence(token.lower())[0] for token in word_tokenize(test_1)]

# %%
import pandas as pd
  
#Tokens that don't exist in transition matrix assigned random values
dat = [[0.01], [0.01], [0.01],[0.01], [0.01], [0.01],[0.01]]
  
# Create the pandas DataFrame
df3 = pd.DataFrame(dat, columns=['Word'])
  
for token in tokens:
    if token in list(df.columns.values):
        matrix = df[token].multiply(df2.loc[previous])
        previous = df.index[np.argmax(matrix)]
        token_label_pair = (token,previous)
        list_of_entity.append(token_label_pair)
    else:
        matrix = df3["Word"].multiply(df2.loc[previous])
        previous = df.index[np.argmax(matrix)]
        token_label_pair = (token,previous)
        list_of_entity.append(token_label_pair)

# %%
pred=[]
for x in list_of_entity:
    if len(x) ==2:
        pred.append(x[1])
print(pred)
# Out:
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOCATION', 'I-LOCATION', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOCATION', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'I-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'I-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'I-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORGANIZATION', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'I-PERSON', 'O', 'O', 'B-ORGANIZATION', 'I-ORGANIZATION', 'B-ORGANIZATION', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'O', 'O', 'B-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'I-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORGANIZATION', 'O', 'B-ORGANIZATION', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORGANIZATION', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORGANIZATION', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORGANIZATION', 'I-ORGANIZATION', 'B-ORGANIZATION', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORGANIZATION', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOCATION', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOCATION', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOCATION', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'O', 'O', 'O', 'B-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORGANIZATION', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O',  ...

# %%
print(len(m_test))
print(len(pred))
# Out:
# 49600
# 49600

# %%
print(metrics.classification_report(m_test, pred))
# Out:
#                 precision    recall  f1-score   support
#
#     B-LOCATION       0.79      0.86      0.82      1126
# B-ORGANIZATION       0.85      0.55      0.67       873
#       B-PERSON       0.89      0.75      0.81      1603
#     I-LOCATION       0.75      0.33      0.46       211
# I-ORGANIZATION       0.63      0.15      0.24       864
#       I-PERSON       0.91      0.52      0.67       803
#              O       0.96      1.00      0.98     44120
#
#       accuracy                           0.95     49600
#      macro avg       0.83      0.59      0.66     49600
#   weighted avg       0.95      0.95      0.94     49600

# %%
#Another test data
with open("PATH",encoding="utf8") as fh:
    test_lines = fh.readlines()

# %%
array_tutucu=[]
t_tutucu=[]
m_test=[]
for asa in test_lines:
    k=asa.split()
    array_tutucu.append(k)
for x in array_tutucu:
    if len(x) ==2:
        m_test.append(x[1])
print(len(m_test))
# Out:
# 45532

# %%
testMetin=""
for test in array_tutucu:
    if len(test)==2:
        testMetin = testMetin + test[0] +" "
print(testMetin)
# Out:
# Lav mermisinin sokak lambası direğine ve tabelaya çarptıktan sonra pencere pervazını parçalayarak birinci kat tavanına saplandığı belirlenirken , Aksaray Polis Karakolu olarak kullanılan birinci katta büyük çaplı hasar meydana geldi Başkan Yılmaz ' ın sürpriz kararla , eski yöneticilerle bugün bir toplantı yapacağını açıklaması , dikkatlerin Trabzonspor ' a çevrilmesine ve Fenerbahçe maçı öncesi gündemi değiştirmesine neden oldu DYP Genel Başkan Yardımcısı Mehmet Gölhan , 488 milletvekilinin oyuyla 18 Nisan 1999 ' da yapılması kabul edilen seçim tarihinin tartışma konusu yapılması veya genel seçimlerin ayrılmasının , TBMM ' ye olan güveni sarsacağını söyledi Bu tutarsızlıklardan dolayı , 1 milyar 160 milyon doları bulup bulamayacağı , Petrol Ofisi işini gerçekten yapıp yapamayacağı belli olmadan ihalede birinci olan ve otomatikman işi " hak eden " Hayyam Garipoğl u da yargıya gitmek için kendisine gayet haklı bir " hakk - ı müktesep " yaratmıştır Bu tabii , belirli bir takımın taraftarlarına özgü bir olay değil Recai Bey ' in mesajı , ' sisteme ve demokratik kurallara uyumlu adımlar attıkları , ancak , bekledikleri karşı adımların gelmediği " yönünde Göç - işsizlik - iş - geçim - çocuk - şiddet gibi bir silsilenin sillesi , sadece sonuçlara bakarak " şu sorunu , bu sorunu " diye adlandırmakla yetindiğimiz , sadece dışavurumlarına karşı öfkelenip kılıç salladığımız bir omurgayı kökünden sarstı , sarsıyor Milne , Campbell için ise , ' O ' nun da zamana ihtiyacı var . Zamanla çok daha iyi olacak " diye konuştu Diğer ülkelerin kolaylık göstermesi lazım Atçılardan aldığımız izlenime göre , ihalede atların 40 milyar liradan 60 milyar liraya kadar satılacaktır ' ' dedi Şaşılası bir şey ama , şu ortamda bizim gibilerin , bir şeyleri engellemek için , yapabilecekleri hiçbir şey yok ne yazık ki Küçük bir şehir görünümünü andıran otelde , Diyarbakır ' lılar birçok yenilikle tanıştı Yeldeğirmenleri bunun kanıtı Komünistlerle kimse işbirliği yapmak istemediğine göre : " Hıristiyan Demokrat + Hür Demokrat " mı Ancak aradan geçen süre içinde Batı ' nın sağladığı kazançların hiç de önemsiz olmadığı anlaşıldı İşlem hacmi geçen hafta cuma gününe göre yüzde 32 gerileyerek 40 , 2 trilyon liraya düştü Zor kurtarır Fransa ile Belçika adalet bakanlıkları arasındaki ilişkiler , daha çok askeri uçak üreten Fransız Dassault fabrikası sahibinin , Paris ' te , Agusta - Dassault rüşvet davasıyla ilgili şahit olarak değil , sanık olarak dinlenmesi üzerine gerginleşmişti Kapanan işyeri sayısı ve işsizliğin artmasına dikkat çekildi Size göre Amerika Kürt devletinin kuruluşuna sıcak bakıyor mu Birini taze yitirdik , ikincisi gideli yıllar oluyor Konuyla ilgili olarak bir konuşma yapan Newt Gringrich , Yargı Kurulu geçen hafta Clinton davasıyla ilgili ( kaset hariç ) neredeyse tüm belge ve kanıtları halka ve basına açıklayacağına dair karar aldı , böyle bir karar verdikten sonra bilgiyi esirgemek olmaz . İnsanların bunları bilmeye hakkı var " şeklinde konuştu Normalde , 8 . Daire , kararını ancak 2 ay içinde verebilir SERGİO : Kendini gösterecek zaman bulamadı Ve Cumhuriyet ' in 75 . yılında İstiklal Savaşı gazilerinin anısını yaşatacak şu öneriyi gündeme getiriyor : " Darphane ' de Cumhuriyet ' in 75 ' inci yıl anısına , İstiklal Savaşı ' nda İstiklal Madalyası ile onurlandırılanlar için , günlük elbise yakalarında devamlı taşınabilecek büyüklükte İstiklal Madalyası nişanları yaptırılmasını öneriyorum . Batı ülkelerinde devlet madalyaları törenlerde kuşanılır . Bu madalyaların küçültülmüş nişanlarını ise sahipleri devamlı olarak yakalarında taşıyabilir . Bizim İstiklal Madalyalarımız da büyük boydur . Devamlı taşınma imkanı yoktur . İzninizle İstiklal Madalyası ' nın ne olduğunu hatırlatayım . Kurtuluş Savaşı ' ndan sonra Mustafa Kemal 23 Nisan 1920 ' de Ankara ' da Meclis ' i topladı . Meclis 1 numaralı kanun olarak " TBMM ' nin Sureti Teşekkülü Hakkında Heyeti Umumiye Kararı ' nı kabul etti . Mustafa Kemal ' in 29 Kasım 1920 tarihinde Meclis ' ten çıkardığı ...

# %%
test_1= testMetin
list_of_entity = []
previous = "<s>"
tokens = [lemmatize_sentence(token.lower())[0] for token in word_tokenize(test_1)]

# %%
import pandas as pd
  
# initialize list of lists
dat = [[0.01], [0.01], [0.01],[0.01], [0.01], [0.01],[0.01]]
  
# Create the pandas DataFrame
df3 = pd.DataFrame(dat, columns=['Word'])
  
for token in tokens:
    if token in list(df.columns.values):
        matrix = df[token].multiply(df2.loc[previous])
        previous = df.index[np.argmax(matrix)]
        token_label_pair = (token,previous)
        list_of_entity.append(token_label_pair)
    else:
        matrix = df3["Word"].multiply(df2.loc[previous])
        previous = df.index[np.argmax(matrix)]
        token_label_pair = (token,previous)
        list_of_entity.append(token_label_pair)

# %%
pred=[]
for x in list_of_entity:
    if len(x) ==2:
        pred.append(x[1])
print(pred)
# Out:
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOCATION', 'O', 'B-LOCATION', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORGANIZATION', 'O', 'O', 'O', 'O', 'B-ORGANIZATION', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORGANIZATION', 'I-ORGANIZATION', 'O', 'O', 'B-PERSON', 'B-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORGANIZATION', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'I-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'O', 'B-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOCATION', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOCATION', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOCATION', 'O', 'B-LOCATION', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORGANIZATION', 'I-ORGANIZATION', 'O', 'O', 'B-LOCATION', 'O', 'O', 'O', 'B-ORGANIZATION', 'I-ORGANIZATION', 'I-ORGANIZATION', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOCATION', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORGANIZATION', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOCATION', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'I-PERSON', 'O', 'O', 'O', 'O', 'O', 'B-LOCATION', 'O', 'O', 'B-ORGANIZATION', 'O', 'O', 'O', 'O', 'B-ORGANIZATION', 'O', 'O', 'O', 'O', 'O', 'B-ORGANIZATION', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'I-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORGANIZATION', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOCATION', 'O', 'O', 'B-ORGANIZATION', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', ...

# %%
print(len(m_test))
print(len(pred))
# Out:
# 45532
# 45532

# %%
print(metrics.classification_report(m_test, pred))
# Out:
#                 precision    recall  f1-score   support
#
#     B-LOCATION       0.81      0.92      0.86       942
# B-ORGANIZATION       0.87      0.66      0.75       842
#       B-PERSON       0.90      0.86      0.88      1400
#     I-LOCATION       0.68      0.53      0.60       107
# I-ORGANIZATION       0.68      0.25      0.37       589
#       I-PERSON       0.90      0.68      0.77       680
#              O       0.98      0.99      0.99     40972
#
#       accuracy                           0.97     45532
#      macro avg       0.83      0.70      0.75     45532
#   weighted avg       0.96      0.97      0.96     45532
